# %%
# Importación de librerías.

import gzip
import pandas as pd
import ast

# %% [markdown]
# ### Extracción de datos

# %%
archivo = '../Datasets/steam_games.json.gz'

df = pd.read_json(archivo, lines=True, encoding='utf-8')

# %%
df.head()
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url specs  \
# 0      None   None     None  None  None         None  None        None  None
# 1      None   None     None  None  None         None  None        None  None
# 2      None   None     None  None  None         None  None        None  None
# 3      None   None     None  None  None         None  None        None  None
# 4      None   None     None  None  None         None  None        None  None
#
#   price  early_access  id developer
# 0  None           NaN NaN      None
# 1  None           NaN NaN      None
# 2  None           NaN NaN      None
# 3  None           NaN NaN      None
# 4  None           NaN NaN      None

# %% [markdown]
# ### Eliminación de columnas y normalización

# %%
# Dropeamos todas las filas vacías
df.dropna(how='all', inplace=True)

# %%
df.head()
# Out:
#               publisher                                             genres  \
# 88310         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313              彼岸领域                        [Action, Adventure, Casual]
# 88314              None                                               None
#
#                       app_name                    title  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313                  弹炸人2222                  弹炸人2222
# 88314            Log Challenge                     None
#
#                                                      url release_date  \
# 88310  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 88311  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 88312  http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 88313     http://store.steampowered.com/app/767400/2222/   2017-12-07
# 88314  http://store.steampowered.com/app/773570/Log_C...         None
#
#                                                     tags  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                        [Action, Adventure, Casual]
# 88314                    [Action, Indie, Casual, Sports]
#
#                                              reviews_url  \
# 88310  http://steamcommunity.com/app/761140/reviews/?...
# 88311  http://steamcommunity.com/app/643980/reviews/?...
# 88312  http://steamcommunity.com/app/670290/reviews/?...
# 88313  http://steamcommunity.com/app/767400/reviews/?...
# 88314  http://steamcommunity.com/app/773570/reviews/?...
#
#                                                    specs         price  \
# 88310                                    [Single-player]          4.99
# 88311  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 88312  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 88313                                    [Single-player]          0.99
# 88314  [Single-player, Full controller support, HTC V...          2.99
#
#        early_access        id         developer
# 88310           0.0  761140.0         Kotoshiro
# 88311           0.0  643980.0  Secret Level SRL
# 88312           0.0  670290.0      Poolians.com
# 88313           0.0  767400.0              彼岸领域
# 88314           0.0  773570.0              None

# %%
# Columnas innecesarias para las consultas
df.drop(columns=['publisher', 'url', 'reviews_url', 'early_access', 'specs'], inplace=True)

# %%
df.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88314                                               None
#
#                       app_name                    title release_date  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty   2018-01-04
# 88311                Ironbound                Ironbound   2018-01-04
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians   2017-07-24
# 88313                  弹炸人2222                  弹炸人2222   2017-12-07
# 88314            Log Challenge                     None         None
#
#                                                     tags         price  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]          4.99
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...  Free To Play
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...  Free to Play
# 88313                        [Action, Adventure, Casual]          0.99
# 88314                    [Action, Indie, Casual, Sports]          2.99
#
#              id         developer
# 88310  761140.0         Kotoshiro
# 88311  643980.0  Secret Level SRL
# 88312  670290.0      Poolians.com
# 88313  767400.0              彼岸领域
# 88314  773570.0              None

# %%
df.shape
# Out:
# (32135, 8)

# %%
df['title'].isna().sum()
# Out:
# 2050

# %%
df[['app_name', 'title']].sample(20)
# Out:
#                                                 app_name  \
# 101495                      Achievement Hunter: Zombie 3
# 103123     Museu do Círio de Nazaré em Realidade Virtual
# 108556                            Line of Sight: Vietnam
# 107884                         The World 3:Rise of Demon
# 115071                                          Mainland
# 104802                                              ISEE
# 118910                         Viking: Battle for Asgard
# 110639              Command LIVE - Old Grudges Never Die
# 115998  X-Plane 10 AddOn - Aerosoft - Airport Wilmington
# 103576                                 The Power Factory
# 104834                        The Houchi Play Soundtrack
# 104840                                Underworld Dungeon
# 106596                                         Zup! Zero
# 115848                        Déjà Vu: MacVenture Series
# 110387                        Driftwood The Visual Novel
# 109059                                Grimm: Dark Legacy
# 112272                      12 is Better Than 6 Art Book
# 96370            Virtual Battlemap DLC - Castles & Chill
# 90293                                         Cloudbuilt
# 100257                                             Relik
#
#                                                    title
# 101495                      Achievement Hunter: Zombie 3
# 103123                                              None
# 108556                            Line of Sight: Vietnam
# 107884                         The World 3:Rise of Demon
# 115071                                          Mainland
# 104802                                              ISEE
# 118910                         Viking: Battle for Asgard
# 110639              Command LIVE - Old Grudges Never Die
# 115998  X-Plane 10 AddOn - Aerosoft - Airport Wilmington
# 103576                                 The Power Factory
# 104834                        The Houchi Play Soundtrack
# 104840                                Underworld Dungeon
# 106596                                         Zup! Zero
# 115848                        Déjà Vu: MacVenture Series
# 110387                        Driftwood The Visual Novel
# 109059                                Grimm: Dark Legacy
# 112272                      12 is Better Than 6 Art Book
# 96370        Virtual Battlemap DLC - Castles &amp; Chill
# 90293                                         Cloudbuilt
# 100257                                             Relik

# %%
df['app_name'].isna().sum()
# Out:
# 2

# %%
# Dropeamos title ya que los valores coinciden con app_name y tiene menos valores nulos
df.drop('title', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88314                                               None
#
#                       app_name release_date  \
# 88310      Lost Summoner Kitty   2018-01-04
# 88311                Ironbound   2018-01-04
# 88312  Real Pool 3D - Poolians   2017-07-24
# 88313                  弹炸人2222   2017-12-07
# 88314            Log Challenge         None
#
#                                                     tags         price  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]          4.99
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...  Free To Play
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...  Free to Play
# 88313                        [Action, Adventure, Casual]          0.99
# 88314                    [Action, Indie, Casual, Sports]          2.99
#
#              id         developer
# 88310  761140.0         Kotoshiro
# 88311  643980.0  Secret Level SRL
# 88312  670290.0      Poolians.com
# 88313  767400.0              彼岸领域
# 88314  773570.0              None

# %%
df['tags'].isna().sum()
# Out:
# 163

# %%
df['genres'].isna().sum()
# Out:
# 3283

# %%
df['price'].unique()
# Out:
# array([4.99, 'Free To Play', 'Free to Play', 0.99, 2.99, 3.99, 9.99,
#        18.99, 29.99, None, 'Free', 10.99, 1.5899999999999999, 14.99, 1.99,
#        59.99, 8.99, 6.99, 7.99, 39.99, 19.99, 7.49, 12.99, 5.99, 2.49,
#        15.99, 1.25, 24.99, 17.99, 61.99, 3.49, 11.99, 13.99, 'Free Demo',
#        'Play for Free!', 34.99, 74.76, 1.49, 32.99, 99.99, 14.95, 69.99,
#        16.99, 79.99, 49.99, 5.0, 44.99, 13.98, 29.96, 119.99, 109.99,
#        149.99, 771.71, 'Install Now', 21.99, 89.99,
#        'Play WARMACHINE: Tactics Demo', 0.98, 139.92, 4.29, 64.99,
#        'Free Mod', 54.99, 74.99, 'Install Theme', 0.89, 'Third-party',
#        0.5, 'Play Now', 299.99, 1.29, 3.0, 15.0, 5.49, 23.99, 49.0, 20.99,
#        10.93, 1.3900000000000001, 'Free HITMAN™ Holiday Pack', 36.99,
#        4.49, 2.0, 4.0, 9.0, 234.99, 1.9500000000000002, 1.5, 199.0, 189.0,
#        6.66, 27.99, 10.49, 129.99, 179.0, 26.99, 399.99, 31.99, 399.0,
#        20.0, 40.0, 3.33, 199.99, 22.99, 320.0, 38.85, 71.7, 59.95, 995.0,
#        27.49, 3.39, 6.0, 19.95, 499.99, 16.06, 4.68, 131.4, 44.98, 202.76,
#        1.0, 2.3, 0.9500000000000001, 172.24, 249.99, 2.9699999999999998,
#        10.96, 10.0, 30.0, 2.66, 6.48, 19.29, 11.15, 18.9, 2.89,
#        'Play the Demo', 99.0, 87.94, 599.0, 8.98, 9.69, 0.49, 9.98, 9.95,
#        7.0, 'Starting at $499.00', 'Starting at $449.00', 12.89, 6.49,
#        1.87, 42.99, 41.99, 289.99, 'Free to Try', 23.96, 5.65, 12.0,
#        13.37, 189.96, 124.99, 'Free Movie', 19.98, 160.91, 'Free to Use'],
#       dtype=object)

# %%
df.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88314                                               None
#
#                       app_name release_date  \
# 88310      Lost Summoner Kitty   2018-01-04
# 88311                Ironbound   2018-01-04
# 88312  Real Pool 3D - Poolians   2017-07-24
# 88313                  弹炸人2222   2017-12-07
# 88314            Log Challenge         None
#
#                                                     tags         price  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]          4.99
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...  Free To Play
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...  Free to Play
# 88313                        [Action, Adventure, Casual]          0.99
# 88314                    [Action, Indie, Casual, Sports]          2.99
#
#              id         developer
# 88310  761140.0         Kotoshiro
# 88311  643980.0  Secret Level SRL
# 88312  670290.0      Poolians.com
# 88313  767400.0              彼岸领域
# 88314  773570.0              None

# %% [markdown]
# ### Transformaciones

# %%
# Dropeamos las filas que tengan valores nulos.

df.dropna(inplace=True)

# %%
# Definimos una función para convertir los precios a float.
def price_to_float(price):
    
    # Si el precio es un string, su valor será 0.
    if type(price) == str:
        return float(0)
    # Si el precio no es un string, lo convertimos a float.
    else:
        return float(price)

df['price'] = df['price'].apply(price_to_float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27449 entries, 88310 to 120443
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genres        27449 non-null  object
#  1   app_name      27449 non-null  object
#  2   release_date  27449 non-null  object
#  3   tags          27449 non-null  object
#  4   price         27449 non-null  float64
#  5   id            27449 non-null  float64
#  6   developer     27449 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 1.7+ MB

# %%
# Convertimos la columna 'release_date' a datetime.

df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27449 entries, 88310 to 120443
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genres        27449 non-null  object
#  1   app_name      27449 non-null  object
#  2   release_date  27410 non-null  datetime64[ns]
#  3   tags          27449 non-null  object
#  4   price         27449 non-null  float64
#  5   id            27449 non-null  float64
#  6   developer     27449 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 1.7+ MB

# %%
df.dropna(subset='release_date', inplace=True)

# %%
df.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88315                    [Action, Adventure, Simulation]
#
#                       app_name release_date  \
# 88310      Lost Summoner Kitty   2018-01-04
# 88311                Ironbound   2018-01-04
# 88312  Real Pool 3D - Poolians   2017-07-24
# 88313                  弹炸人2222   2017-12-07
# 88315    Battle Royale Trainer   2018-01-04
#
#                                                     tags  price        id  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]   4.99  761140.0
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...   0.00  643980.0
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...   0.00  670290.0
# 88313                        [Action, Adventure, Casual]   0.99  767400.0
# 88315  [Action, Adventure, Simulation, FPS, Shooter, ...   3.99  772540.0
#
#                  developer
# 88310            Kotoshiro
# 88311     Secret Level SRL
# 88312         Poolians.com
# 88313                 彼岸领域
# 88315  Trickjump Games Ltd

# %%
# Renombramos app_name por title.

df.rename(columns={'app_name': 'title'}, inplace=True)

# Renombramos la columna id que corresponde a item_id, y la convertimos a string.

df.rename(columns={'id': 'item_id'}, inplace=True)

df['item_id'] = df['item_id'].astype(str).str.split('.').str[0]

# %% [markdown]
# #### Nota: para optimizar el costo computacional, no vamos a utilizar valores numéricos en item_id ya que no necesitamos operar sobre ellos, solo los vamos a usar para unir las tablas.

# %%
df.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88315                    [Action, Adventure, Simulation]
#
#                          title release_date  \
# 88310      Lost Summoner Kitty   2018-01-04
# 88311                Ironbound   2018-01-04
# 88312  Real Pool 3D - Poolians   2017-07-24
# 88313                  弹炸人2222   2017-12-07
# 88315    Battle Royale Trainer   2018-01-04
#
#                                                     tags  price item_id  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]   4.99  761140
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...   0.00  643980
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...   0.00  670290
# 88313                        [Action, Adventure, Casual]   0.99  767400
# 88315  [Action, Adventure, Simulation, FPS, Shooter, ...   3.99  772540
#
#                  developer
# 88310            Kotoshiro
# 88311     Secret Level SRL
# 88312         Poolians.com
# 88313                 彼岸领域
# 88315  Trickjump Games Ltd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27410 entries, 88310 to 120443
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genres        27410 non-null  object
#  1   title         27410 non-null  object
#  2   release_date  27410 non-null  datetime64[ns]
#  3   tags          27410 non-null  object
#  4   price         27410 non-null  float64
#  5   item_id       27410 non-null  object
#  6   developer     27410 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 1.7+ MB

# %%
# Convertimos las listas de 'genres' y 'tags' a strings.

df['genres'] = df['genres'].apply(lambda x: ', '.join(x))
df['tags'] = df['tags'].apply(lambda x: ', '.join(x))

# %%
# Ordenamos las columnas.

new_order = ['item_id', 'title', 'developer', 'release_date', 'genres', 'tags', 'price']

df = df[new_order]

# %%
df.head()
# Out:
#       item_id                    title            developer release_date  \
# 88310  761140      Lost Summoner Kitty            Kotoshiro   2018-01-04
# 88311  643980                Ironbound     Secret Level SRL   2018-01-04
# 88312  670290  Real Pool 3D - Poolians         Poolians.com   2017-07-24
# 88313  767400                  弹炸人2222                 彼岸领域   2017-12-07
# 88315  772540    Battle Royale Trainer  Trickjump Games Ltd   2018-01-04
#
#                                                 genres  \
# 88310      Action, Casual, Indie, Simulation, Strategy
# 88311               Free to Play, Indie, RPG, Strategy
# 88312  Casual, Free to Play, Indie, Simulation, Sports
# 88313                        Action, Adventure, Casual
# 88315                    Action, Adventure, Simulation
#
#                                                     tags  price
# 88310        Strategy, Action, Indie, Casual, Simulation   4.99
# 88311  Free to Play, Strategy, Indie, RPG, Card Game,...   0.00
# 88312  Free to Play, Simulation, Sports, Casual, Indi...   0.00
# 88313                          Action, Adventure, Casual   0.99
# 88315  Action, Adventure, Simulation, FPS, Shooter, T...   3.99

# %% [markdown]
# ### Exportación del dataset

# %%
# Exportamos el dataset preprocesado a un archivo parquet con compresión snappy.

df.to_parquet('../Datasets/steam_games_preprocessed.parquet', compression='snappy', index=False)
