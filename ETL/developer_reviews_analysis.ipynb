# %%
import pandas as pd

# %%
df_games = pd.read_parquet('../Datasets/steam_games_preprocessed.parquet')
df_reviews = pd.read_parquet('../Datasets/user_reviews_preprocessed.parquet')

# %%
df_games
# Out:
#       item_id                     title                 developer  \
# 0      761140       Lost Summoner Kitty                 Kotoshiro
# 1      643980                 Ironbound          Secret Level SRL
# 2      670290   Real Pool 3D - Poolians              Poolians.com
# 3      767400                   弹炸人2222                      彼岸领域
# 4      772540     Battle Royale Trainer       Trickjump Games Ltd
# ...       ...                       ...                       ...
# 27405  745400              Kebab it Up!           Bidoniera Games
# 27406  773640            Colony On Mars        Nikita "Ghost_RUS"
# 27407  733530  LOGistICAL: South Africa                    Sacada
# 27408  610660             Russian Roads  Laush Dmitriy Sergeevich
# 27409  658870       EXIT 2 - Directions             xropi,stev3ns
#
#       release_date                                           genres  \
# 0       2018-01-04      Action, Casual, Indie, Simulation, Strategy
# 1       2018-01-04               Free to Play, Indie, RPG, Strategy
# 2       2017-07-24  Casual, Free to Play, Indie, Simulation, Sports
# 3       2017-12-07                        Action, Adventure, Casual
# 4       2018-01-04                    Action, Adventure, Simulation
# ...            ...                                              ...
# 27405   2018-01-04                 Action, Adventure, Casual, Indie
# 27406   2018-01-04              Casual, Indie, Simulation, Strategy
# 27407   2018-01-04                          Casual, Indie, Strategy
# 27408   2018-01-04                        Indie, Racing, Simulation
# 27409   2017-09-02                                    Casual, Indie
#
#                                                     tags  price
# 0            Strategy, Action, Indie, Casual, Simulation   4.99
# 1      Free to Play, Strategy, Indie, RPG, Card Game,...   0.00
# 2      Free to Play, Simulation, Sports, Casual, Indi...   0.00
# 3                              Action, Adventure, Casual   0.99
# 4      Action, Adventure, Simulation, FPS, Shooter, T...   3.99
# ...                                                  ...    ...
# 27405          Action, Indie, Casual, Violent, Adventure   1.99
# 27406                Strategy, Indie, Casual, Simulation   1.99
# 27407                            Strategy, Indie, Casual   4.99
# 27408                          Indie, Simulation, Racing   1.99
# 27409  Indie, Casual, Puzzle, Singleplayer, Atmospher...   4.99
#
# [27410 rows x 7 columns]

# %%
df_reviews
# Out:
#       item_id  recommend            user_id  sentiment_analysis
# 0        1250       True  76561197970982479                   2
# 1       22200       True  76561197970982479                   2
# 2       43110       True  76561197970982479                   2
# 3      251610       True            js41637                   2
# 4      227300       True            js41637                   0
# ...       ...        ...                ...                 ...
# 58426      70       True  76561198312638244                   2
# 58427  362890       True  76561198312638244                   2
# 58428  273110       True        LydiaMorley                   2
# 58429     730       True        LydiaMorley                   2
# 58430     440       True        LydiaMorley                   2
#
# [58431 rows x 4 columns]

# %%
df = pd.merge(df_reviews, df_games, on='item_id', how='inner')

# %%
# Columnas necesarias para el endpoint
df = df[['developer', 'sentiment_analysis']]

# %%
df.to_parquet('../Datasets/developer_reviews_analysis.parquet', compression='snappy', index=False)
